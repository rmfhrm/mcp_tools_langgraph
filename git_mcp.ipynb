# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
from langchain_mcp_adapters.client import MultiServerMCPClient

github_pat = os.getenv("GITHUB_PAT")

mcp_client = MultiServerMCPClient({   
    "github": {
      "url": "https://api.githubcopilot.com/mcp/",  # GitHub Copilot MCP API 엔드포인트
      "headers": {
        "Authorization": f"Bearer {github_pat}"  # Bearer 토큰 인증
      },
      "transport": "streamable_http"  # 새로운 표준 transport 방식
    }
})

# %%
tool_list = await mcp_client.get_tools()

# %%
tool_list
# Out:
# [StructuredTool(name='add_comment_to_pending_review', description="Add review comment to the requester's latest pending pull request review. A pending review needs to already exist to call this (check with the user if not sure).", args_schema={'properties': {'body': {'description': 'The text of the review comment', 'type': 'string'}, 'line': {'description': 'The line of the blob in the pull request diff that the comment applies to. For multi-line comments, the last line of the range', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'path': {'description': 'The relative path to the file that necessitates a comment', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'side': {'description': 'The side of the diff to comment on. LEFT indicates the previous state, RIGHT indicates the new state', 'enum': ['LEFT', 'RIGHT'], 'type': 'string'}, 'startLine': {'description': 'For multi-line comments, the first line of the range that the comment applies to', 'type': 'number'}, 'startSide': {'description': 'For multi-line comments, the starting side of the diff that the comment applies to. LEFT indicates the previous state, RIGHT indicates the new state', 'enum': ['LEFT', 'RIGHT'], 'type': 'string'}, 'subjectType': {'description': 'The level at which the comment is targeted', 'enum': ['FILE', 'LINE'], 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber', 'path', 'body', 'subjectType'], 'type': 'object'}, metadata={'title': "Add review comment to the requester's latest pending pull request review", 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6DD2B5F80>),
#  StructuredTool(name='add_issue_comment', description='Add a comment to a specific issue in a GitHub repository.', args_schema={'properties': {'body': {'description': 'Comment content', 'type': 'string'}, 'issue_number': {'description': 'Issue number to comment on', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'issue_number', 'body'], 'type': 'object'}, metadata={'title': 'Add comment to issue', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16120C0>),
#  StructuredTool(name='add_sub_issue', description='Add a sub-issue to a parent issue in a GitHub repository.', args_schema={'properties': {'issue_number': {'description': 'The number of the parent issue', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'replace_parent': {'description': "When true, replaces the sub-issue's current parent issue", 'type': 'boolean'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'sub_issue_id': {'description': 'The ID of the sub-issue to add. ID is not the same as issue number', 'type': 'number'}}, 'required': ['owner', 'repo', 'issue_number', 'sub_issue_id'], 'type': 'object'}, metadata={'title': 'Add sub-issue', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1611C60>),
#  StructuredTool(name='assign_copilot_to_issue', description='Assign Copilot to a specific issue in a GitHub repository.\n\nThis tool can help with the following outcomes:\n- a Pull Request created with source code changes to resolve the issue\n\n\nMore information can be found at:\n- https://docs.github.com/en/copilot/using-github-copilot/using-copilot-coding-agent-to-work-on-tasks/about-assigning-tasks-to-copilot\n', args_schema={'properties': {'issueNumber': {'description': 'Issue number', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'issueNumber'], 'type': 'object'}, metadata={'title': 'Assign Copilot to issue', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': True, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16123E0>),
#  StructuredTool(name='cancel_workflow_run', description='Cancel a workflow run', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'run_id': {'description': 'The unique identifier of the workflow run', 'type': 'number'}}, 'required': ['owner', 'repo', 'run_id'], 'type': 'object'}, metadata={'title': 'Cancel workflow run', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612480>),
#  StructuredTool(name='create_and_submit_pull_request_review', description='Create and submit a review for a pull request without review comments.', args_schema={'properties': {'body': {'description': 'Review comment text', 'type': 'string'}, 'commitID': {'description': 'SHA of commit to review', 'type': 'string'}, 'event': {'description': 'Review action to perform', 'enum': ['APPROVE', 'REQUEST_CHANGES', 'COMMENT'], 'type': 'string'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber', 'body', 'event'], 'type': 'object'}, metadata={'title': 'Create and submit a pull request review without comments', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1610EA0>),
#  StructuredTool(name='create_branch', description='Create a new branch in a GitHub repository', args_schema={'properties': {'branch': {'description': 'Name for new branch', 'type': 'string'}, 'from_branch': {'description': 'Source branch (defaults to repo default)', 'type': 'string'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'branch'], 'type': 'object'}, metadata={'title': 'Create branch', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612520>),
#  StructuredTool(name='create_gist', description='Create a new gist', args_schema={'properties': {'content': {'description': 'Content for simple single-file gist creation', 'type': 'string'}, 'description': {'description': 'Description of the gist', 'type': 'string'}, 'filename': {'description': 'Filename for simple single-file gist creation', 'type': 'string'}, 'public': {'default': False, 'description': 'Whether the gist is public', 'type': 'boolean'}}, 'required': ['filename', 'content'], 'type': 'object'}, metadata={'title': 'Create Gist', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16125C0>),
#  StructuredTool(name='create_issue', description='Create a new issue in a GitHub repository.', args_schema={'properties': {'assignees': {'description': 'Usernames to assign to this issue', 'items': {'type': 'string'}, 'type': 'array'}, 'body': {'description': 'Issue body content', 'type': 'string'}, 'labels': {'description': 'Labels to apply to this issue', 'items': {'type': 'string'}, 'type': 'array'}, 'milestone': {'description': 'Milestone number', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'title': {'description': 'Issue title', 'type': 'string'}, 'type': {'description': 'Type of this issue', 'type': 'string'}}, 'required': ['owner', 'repo', 'title'], 'type': 'object'}, metadata={'title': 'Open new issue', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1610F40>),
#  StructuredTool(name='create_or_update_file', description='Create or update a single file in a GitHub repository. If updating, you must provide the SHA of the file you want to update. Use this tool to create or update a file in a GitHub repository remotely; do not use it for local file operations.', args_schema={'properties': {'branch': {'description': 'Branch to create/update the file in', 'type': 'string'}, 'content': {'description': 'Content of the file', 'type': 'string'}, 'message': {'description': 'Commit message', 'type': 'string'}, 'owner': {'description': 'Repository owner (username or organization)', 'type': 'string'}, 'path': {'description': 'Path where to create/update the file', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'sha': {'description': 'Required if updating an existing file. The blob SHA of the file being replaced.', 'type': 'string'}}, 'required': ['owner', 'repo', 'path', 'content', 'message', 'branch'], 'type': 'object'}, metadata={'title': 'Create or update file', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612660>),
#  StructuredTool(name='create_pending_pull_request_review', description='Create a pending review for a pull request. Call this first before attempting to add comments to a pending review, and ultimately submitting it. A pending pull request review means a pull request review, it is pending because you create it first and submit it later, and the PR author will not see it until it is submitted.', args_schema={'properties': {'commitID': {'description': 'SHA of commit to review', 'type': 'string'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber'], 'type': 'object'}, metadata={'title': 'Create pending pull request review', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612700>),
#  StructuredTool(name='create_pull_request', description='Create a new pull request in a GitHub repository.', args_schema={'properties': {'base': {'description': 'Branch to merge into', 'type': 'string'}, 'body': {'description': 'PR description', 'type': 'string'}, 'draft': {'description': 'Create as draft PR', 'type': 'boolean'}, 'head': {'description': 'Branch containing changes', 'type': 'string'}, 'maintainer_can_modify': {'description': 'Allow maintainer edits', 'type': 'boolean'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'title': {'description': 'PR title', 'type': 'string'}}, 'required': ['owner', 'repo', 'title', 'head', 'base'], 'type': 'object'}, metadata={'title': 'Open new pull request', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16127A0>),
#  StructuredTool(name='create_pull_request_with_copilot', description='Delegate a task to GitHub Copilot coding agent to perform in the background. The agent will create a pull request with the implementation. You should use this tool if the user asks to create a pull request to perform a specific task, or if the user asks Copilot to do something.', args_schema={'properties': {'base_ref': {'description': "Git reference (e.g., branch) that the agent will start its work from. If not specified, defaults to the repository's default branch", 'type': 'string'}, 'owner': {'description': 'Repository owner. You can guess the owner, but confirm it with the user before proceeding.', 'type': 'string'}, 'problem_statement': {'description': "Detailed description of the task to be performed (e.g., 'Implement a feature that does X', 'Fix bug Y', etc.)", 'type': 'string'}, 'repo': {'description': 'Repository name. You can guess the repository name, but confirm it with the user before proceeding.', 'type': 'string'}, 'title': {'description': 'Title for the pull request that will be created', 'type': 'string'}}, 'required': ['owner', 'repo', 'problem_statement', 'title'], 'type': 'object'}, metadata={'title': 'Perform task with GitHub Copilot coding agent', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1610E00>),
#  StructuredTool(name='create_repository', description='Create a new GitHub repository in your account or specified organization', args_schema={'properties': {'autoInit': {'description': 'Initialize with README', 'type': 'boolean'}, 'description': {'description': 'Repository description', 'type': 'string'}, 'name': {'description': 'Repository name', 'type': 'string'}, 'organization': {'description': 'Organization to create the repository in (omit to create in your personal account)', 'type': 'string'}, 'private': {'description': 'Whether repo should be private', 'type': 'boolean'}}, 'required': ['name'], 'type': 'object'}, metadata={'title': 'Create repository', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612840>),
#  StructuredTool(name='delete_file', description='Delete a file from a GitHub repository', args_schema={'properties': {'branch': {'description': 'Branch to delete the file from', 'type': 'string'}, 'message': {'description': 'Commit message', 'type': 'string'}, 'owner': {'description': 'Repository owner (username or organization)', 'type': 'string'}, 'path': {'description': 'Path to the file to delete', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'path', 'message', 'branch'], 'type': 'object'}, metadata={'title': 'Delete file', 'readOnlyHint': False, 'destructiveHint': True, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16128E0>),
#  StructuredTool(name='delete_pending_pull_request_review', description="Delete the requester's latest pending pull request review. Use this after the user decides not to submit a pending review, if you don't know if they already created one then check first.", args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber'], 'type': 'object'}, metadata={'title': "Delete the requester's latest pending pull request review", 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612980>),
#  StructuredTool(name='delete_workflow_run_logs', description='Delete logs for a workflow run', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'run_id': {'description': 'The unique identifier of the workflow run', 'type': 'number'}}, 'required': ['owner', 'repo', 'run_id'], 'type': 'object'}, metadata={'title': 'Delete workflow logs', 'readOnlyHint': False, 'destructiveHint': True, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612A20>),
#  StructuredTool(name='dismiss_notification', description='Dismiss a notification by marking it as read or done', args_schema={'properties': {'state': {'description': 'The new state of the notification (read/done)', 'enum': ['read', 'done'], 'type': 'string'}, 'threadID': {'description': 'The ID of the notification thread', 'type': 'string'}}, 'required': ['threadID'], 'type': 'object'}, metadata={'title': 'Dismiss notification', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612AC0>),
#  StructuredTool(name='download_workflow_run_artifact', description='Get download URL for a workflow run artifact', args_schema={'properties': {'artifact_id': {'description': 'The unique identifier of the artifact', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'artifact_id'], 'type': 'object'}, metadata={'title': 'Download workflow artifact', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612B60>),
#  StructuredTool(name='fork_repository', description='Fork a GitHub repository to your account or specified organization', args_schema={'properties': {'organization': {'description': 'Organization to fork to', 'type': 'string'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo'], 'type': 'object'}, metadata={'title': 'Fork repository', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612C00>),
#  StructuredTool(name='get_code_scanning_alert', description='Get details of a specific code scanning alert in a GitHub repository.', args_schema={'properties': {'alertNumber': {'description': 'The number of the alert.', 'type': 'number'}, 'owner': {'description': 'The owner of the repository.', 'type': 'string'}, 'repo': {'description': 'The name of the repository.', 'type': 'string'}}, 'required': ['owner', 'repo', 'alertNumber'], 'type': 'object'}, metadata={'title': 'Get code scanning alert', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612CA0>),
#  StructuredTool(name='get_commit', description='Get details for a commit from a GitHub repository', args_schema={'properties': {'include_diff': {'default': True, 'description': 'Whether to include file diffs and stats in the response. Default is true.', 'type': 'boolean'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'sha': {'description': 'Commit SHA, branch name, or tag name', 'type': 'string'}}, 'required': ['owner', 'repo', 'sha'], 'type': 'object'}, metadata={'title': 'Get commit details', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612D40>),
#  StructuredTool(name='get_dependabot_alert', description='Get details of a specific dependabot alert in a GitHub repository.', args_schema={'properties': {'alertNumber': {'description': 'The number of the alert.', 'type': 'number'}, 'owner': {'description': 'The owner of the repository.', 'type': 'string'}, 'repo': {'description': 'The name of the repository.', 'type': 'string'}}, 'required': ['owner', 'repo', 'alertNumber'], 'type': 'object'}, metadata={'title': 'Get dependabot alert', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612DE0>),
#  StructuredTool(name='get_discussion', description='Get a specific discussion by ID', args_schema={'properties': {'discussionNumber': {'description': 'Discussion Number', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'discussionNumber'], 'type': 'object'}, metadata={'title': 'Get discussion', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612E80>),
#  StructuredTool(name='get_discussion_comments', description='Get comments from a discussion', args_schema={'properties': {'after': {'description': "Cursor for pagination. Use the endCursor from the previous page's PageInfo for GraphQL APIs.", 'type': 'string'}, 'discussionNumber': {'description': 'Discussion Number', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'discussionNumber'], 'type': 'object'}, metadata={'title': 'Get discussion comments', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612F20>),
#  StructuredTool(name='get_file_contents', description='Get the contents of a file or directory from a GitHub repository', args_schema={'properties': {'owner': {'description': 'Repository owner (username or organization)', 'type': 'string'}, 'path': {'default': '/', 'description': "Path to file/directory (directories must end with a slash '/')", 'type': 'string'}, 'ref': {'description': 'Accepts optional git refs such as `refs/tags/{tag}`, `refs/heads/{branch}` or `refs/pull/{pr_number}/head`', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'sha': {'description': 'Accepts optional commit SHA. If specified, it will be used instead of ref', 'type': 'string'}}, 'required': ['owner', 'repo'], 'type': 'object'}, metadata={'title': 'Get file or directory contents', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612FC0>),
#  StructuredTool(name='get_global_security_advisory', description='Get a global security advisory', args_schema={'properties': {'ghsaId': {'description': 'GitHub Security Advisory ID (format: GHSA-xxxx-xxxx-xxxx).', 'type': 'string'}}, 'required': ['ghsaId'], 'type': 'object'}, metadata={'title': 'Get a global security advisory', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613060>),
#  StructuredTool(name='get_issue', description='Get details of a specific issue in a GitHub repository.', args_schema={'properties': {'issue_number': {'description': 'The number of the issue', 'type': 'number'}, 'owner': {'description': 'The owner of the repository', 'type': 'string'}, 'repo': {'description': 'The name of the repository', 'type': 'string'}}, 'required': ['owner', 'repo', 'issue_number'], 'type': 'object'}, metadata={'title': 'Get issue details', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613100>),
#  StructuredTool(name='get_issue_comments', description='Get comments for a specific issue in a GitHub repository.', args_schema={'properties': {'issue_number': {'description': 'Issue number', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'issue_number'], 'type': 'object'}, metadata={'title': 'Get issue comments', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16131A0>),
#  StructuredTool(name='get_job_logs', description='Download logs for a specific workflow job or efficiently get all failed job logs for a workflow run', args_schema={'properties': {'failed_only': {'description': 'When true, gets logs for all failed jobs in run_id', 'type': 'boolean'}, 'job_id': {'description': 'The unique identifier of the workflow job (required for single job logs)', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'return_content': {'description': 'Returns actual log content instead of URLs', 'type': 'boolean'}, 'run_id': {'description': 'Workflow run ID (required when using failed_only)', 'type': 'number'}, 'tail_lines': {'default': 500, 'description': 'Number of lines to return from the end of the log', 'type': 'number'}}, 'required': ['owner', 'repo'], 'type': 'object'}, metadata={'title': 'Get job logs', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613240>),
#  StructuredTool(name='get_latest_release', description='Get the latest release in a GitHub repository', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo'], 'type': 'object'}, metadata={'title': 'Get latest release', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16132E0>),
#  StructuredTool(name='get_me', description="Get details of the authenticated GitHub user. Use this when a request is about the user's own profile for GitHub. Or when information is missing to build other tool calls.", args_schema={'properties': {}, 'type': 'object'}, metadata={'title': 'Get my user profile', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613380>),
#  StructuredTool(name='get_notification_details', description="Get detailed information for a specific GitHub notification, always call this tool when the user asks for details about a specific notification, if you don't know the ID list notifications first.", args_schema={'properties': {'notificationID': {'description': 'The ID of the notification', 'type': 'string'}}, 'required': ['notificationID'], 'type': 'object'}, metadata={'title': 'Get notification details', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613420>),
#  StructuredTool(name='get_pull_request', description='Get details of a specific pull request in a GitHub repository.', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber'], 'type': 'object'}, metadata={'title': 'Get pull request details', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16134C0>),
#  StructuredTool(name='get_pull_request_comments', description='Get comments for a specific pull request.', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber'], 'type': 'object'}, metadata={'title': 'Get pull request comments', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613560>),
#  StructuredTool(name='get_pull_request_diff', description='Get the diff of a pull request.', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber'], 'type': 'object'}, metadata={'title': 'Get pull request diff', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613600>),
#  StructuredTool(name='get_pull_request_files', description='Get the files changed in a specific pull request.', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber'], 'type': 'object'}, metadata={'title': 'Get pull request files', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16136A0>),
#  StructuredTool(name='get_pull_request_reviews', description='Get reviews for a specific pull request.', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber'], 'type': 'object'}, metadata={'title': 'Get pull request reviews', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613740>),
#  StructuredTool(name='get_pull_request_status', description='Get the status of a specific pull request.', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber'], 'type': 'object'}, metadata={'title': 'Get pull request status checks', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16137E0>),
#  StructuredTool(name='get_release_by_tag', description='Get a specific release by its tag name in a GitHub repository', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'tag': {'description': "Tag name (e.g., 'v1.0.0')", 'type': 'string'}}, 'required': ['owner', 'repo', 'tag'], 'type': 'object'}, metadata={'title': 'Get a release by tag name', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6DEB16D40>),
#  StructuredTool(name='get_secret_scanning_alert', description='Get details of a specific secret scanning alert in a GitHub repository.', args_schema={'properties': {'alertNumber': {'description': 'The number of the alert.', 'type': 'number'}, 'owner': {'description': 'The owner of the repository.', 'type': 'string'}, 'repo': {'description': 'The name of the repository.', 'type': 'string'}}, 'required': ['owner', 'repo', 'alertNumber'], 'type': 'object'}, metadata={'title': 'Get secret scanning alert', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1611120>),
#  StructuredTool(name='get_tag', description='Get details about a specific git tag in a GitHub repository', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'tag': {'description': 'Tag name', 'type': 'string'}}, 'required': ['owner', 'repo', 'tag'], 'type': 'object'}, metadata={'title': 'Get tag details', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1612160>),
#  StructuredTool(name='get_team_members', description='Get member usernames of a specific team in an organization. Limited to organizations accessible with current credentials', args_schema={'properties': {'org': {'description': 'Organization login (owner) that contains the team.', 'type': 'string'}, 'team_slug': {'description': 'Team slug', 'type': 'string'}}, 'required': ['org', 'team_slug'], 'type': 'object'}, metadata={'title': 'Get team members', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1610D60>),
#  StructuredTool(name='get_teams', description='Get details of the teams the user is a member of. Limited to organizations accessible with current credentials', args_schema={'properties': {'user': {'description': 'Username to get teams for. If not provided, uses the authenticated user.', 'type': 'string'}}, 'type': 'object'}, metadata={'title': 'Get teams', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1611B20>),
#  StructuredTool(name='get_workflow_run', description='Get details of a specific workflow run', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'run_id': {'description': 'The unique identifier of the workflow run', 'type': 'number'}}, 'required': ['owner', 'repo', 'run_id'], 'type': 'object'}, metadata={'title': 'Get workflow run', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613880>),
#  StructuredTool(name='get_workflow_run_logs', description='Download logs for a specific workflow run (EXPENSIVE: downloads ALL logs as ZIP. Consider using get_job_logs with failed_only=true for debugging failed jobs)', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'run_id': {'description': 'The unique identifier of the workflow run', 'type': 'number'}}, 'required': ['owner', 'repo', 'run_id'], 'type': 'object'}, metadata={'title': 'Get workflow run logs', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613920>),
#  StructuredTool(name='get_workflow_run_usage', description='Get usage metrics for a workflow run', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'run_id': {'description': 'The unique identifier of the workflow run', 'type': 'number'}}, 'required': ['owner', 'repo', 'run_id'], 'type': 'object'}, metadata={'title': 'Get workflow usage', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E16139C0>),
#  StructuredTool(name='list_branches', description='List branches in a GitHub repository', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo'], 'type': 'object'}, metadata={'title': 'List branches', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613A60>),
#  StructuredTool(name='list_code_scanning_alerts', description='List code scanning alerts in a GitHub repository.', args_schema={'properties': {'owner': {'description': 'The owner of the repository.', 'type': 'string'}, 'ref': {'description': 'The Git reference for the results you want to list.', 'type': 'string'}, 'repo': {'description': 'The name of the repository.', 'type': 'string'}, 'severity': {'description': 'Filter code scanning alerts by severity', 'enum': ['critical', 'high', 'medium', 'low', 'warning', 'note', 'error'], 'type': 'string'}, 'state': {'default': 'open', 'description': 'Filter code scanning alerts by state. Defaults to open', 'enum': ['open', 'closed', 'dismissed', 'fixed'], 'type': 'string'}, 'tool_name': {'description': 'The name of the tool used for code scanning.', 'type': 'string'}}, 'required': ['owner', 'repo'], 'type': 'object'}, metadata={'title': 'List code scanning alerts', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613B00>),
#  StructuredTool(name='list_commits', description='Get list of commits of a branch in a GitHub repository. Returns at least 30 results per page by default, but can return more if specified using the perPage parameter (up to 100).', args_schema={'properties': {'author': {'description': 'Author username or email address to filter commits by', 'type': 'string'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'sha': {'description': 'Commit SHA, branch or tag name to list commits of. If not provided, uses the default branch of the repository. If a commit SHA is provided, will list commits up to that SHA.', 'type': 'string'}}, 'required': ['owner', 'repo'], 'type': 'object'}, metadata={'title': 'List commits', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613BA0>),
#  StructuredTool(name='list_dependabot_alerts', description='List dependabot alerts in a GitHub repository.', args_schema={'properties': {'owner': {'description': 'The owner of the repository.', 'type': 'string'}, 'repo': {'description': 'The name of the repository.', 'type': 'string'}, 'severity': {'description': 'Filter dependabot alerts by severity', 'enum': ['low', 'medium', 'high', 'critical'], 'type': 'string'}, 'state': {'default': 'open', 'description': 'Filter dependabot alerts by state. Defaults to open', 'enum': ['open', 'fixed', 'dismissed', 'auto_dismissed'], 'type': 'string'}}, 'required': ['owner', 'repo'], 'type': 'object'}, metadata={'title': 'List dependabot alerts', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613C40>),
#  StructuredTool(name='list_discussion_categories', description='List discussion categories with their id and name, for a repository or organisation.', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name. If not provided, discussion categories will be queried at the organisation level.', 'type': 'string'}}, 'required': ['owner'], 'type': 'object'}, metadata={'title': 'List discussion categories', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613CE0>),
#  StructuredTool(name='list_discussions', description='List discussions for a repository or organisation.', args_schema={'properties': {'after': {'description': "Cursor for pagination. Use the endCursor from the previous page's PageInfo for GraphQL APIs.", 'type': 'string'}, 'category': {'description': 'Optional filter by discussion category ID. If provided, only discussions with this category are listed.', 'type': 'string'}, 'direction': {'description': 'Order direction.', 'enum': ['ASC', 'DESC'], 'type': 'string'}, 'orderBy': {'description': "Order discussions by field. If provided, the 'direction' also needs to be provided.", 'enum': ['CREATED_AT', 'UPDATED_AT'], 'type': 'string'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'repo': {'description': 'Repository name. If not provided, discussions will be queried at the organisation level.', 'type': 'string'}}, 'required': ['owner'], 'type': 'object'}, metadata={'title': 'List discussions', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613D80>),
#  StructuredTool(name='list_gists', description='List gists for a user', args_schema={'properties': {'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'since': {'description': 'Only gists updated after this time (ISO 8601 timestamp)', 'type': 'string'}, 'username': {'description': "GitHub username (omit for authenticated user's gists)", 'type': 'string'}}, 'type': 'object'}, metadata={'title': 'List Gists', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613E20>),
#  StructuredTool(name='list_global_security_advisories', description='List global security advisories from GitHub.', args_schema={'properties': {'affects': {'description': 'Filter advisories by affected package or version (e.g. "package1,package2@1.0.0").', 'type': 'string'}, 'cveId': {'description': 'Filter by CVE ID.', 'type': 'string'}, 'cwes': {'description': 'Filter by Common Weakness Enumeration IDs (e.g. ["79", "284", "22"]).', 'items': {'type': 'string'}, 'type': 'array'}, 'ecosystem': {'description': 'Filter by package ecosystem.', 'enum': ['actions', 'composer', 'erlang', 'go', 'maven', 'npm', 'nuget', 'other', 'pip', 'pub', 'rubygems', 'rust'], 'type': 'string'}, 'ghsaId': {'description': 'Filter by GitHub Security Advisory ID (format: GHSA-xxxx-xxxx-xxxx).', 'type': 'string'}, 'isWithdrawn': {'description': 'Whether to only return withdrawn advisories.', 'type': 'boolean'}, 'modified': {'description': 'Filter by publish or update date or date range (ISO 8601 date or range).', 'type': 'string'}, 'published': {'description': 'Filter by publish date or date range (ISO 8601 date or range).', 'type': 'string'}, 'severity': {'description': 'Filter by severity.', 'enum': ['unknown', 'low', 'medium', 'high', 'critical'], 'type': 'string'}, 'type': {'default': 'reviewed', 'description': 'Advisory type.', 'enum': ['reviewed', 'malware', 'unreviewed'], 'type': 'string'}, 'updated': {'description': 'Filter by update date or date range (ISO 8601 date or range).', 'type': 'string'}}, 'type': 'object'}, metadata={'title': 'List global security advisories', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1613EC0>),
# ...
#  StructuredTool(name='rerun_failed_jobs', description='Re-run only the failed jobs in a workflow run', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'run_id': {'description': 'The unique identifier of the workflow run', 'type': 'number'}}, 'required': ['owner', 'repo', 'run_id'], 'type': 'object'}, metadata={'title': 'Rerun failed jobs', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1704D60>),
#  StructuredTool(name='rerun_workflow_run', description='Re-run an entire workflow run', args_schema={'properties': {'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'run_id': {'description': 'The unique identifier of the workflow run', 'type': 'number'}}, 'required': ['owner', 'repo', 'run_id'], 'type': 'object'}, metadata={'title': 'Rerun workflow run', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1704E00>),
#  StructuredTool(name='run_workflow', description='Run an Actions workflow by workflow ID or filename', args_schema={'properties': {'inputs': {'description': 'Inputs the workflow accepts', 'properties': {}, 'type': 'object'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'ref': {'description': 'The git reference for the workflow. The reference can be a branch or tag name.', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'workflow_id': {'description': 'The workflow ID (numeric) or workflow file name (e.g., main.yml, ci.yaml)', 'type': 'string'}}, 'required': ['owner', 'repo', 'workflow_id', 'ref'], 'type': 'object'}, metadata={'title': 'Run workflow', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1704EA0>),
#  StructuredTool(name='search_code', description="Fast and precise code search across ALL GitHub repositories using GitHub's native search engine. Best for finding exact symbols, functions, classes, or specific code patterns.", args_schema={'properties': {'order': {'description': 'Sort order for results', 'enum': ['asc', 'desc'], 'type': 'string'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'query': {'description': "Search query using GitHub's powerful code search syntax. Examples: 'content:Skill language:Java org:github', 'NOT is:archived language:Python OR language:go', 'repo:github/github-mcp-server'. Supports exact matching, language filters, path filters, and more.", 'type': 'string'}, 'sort': {'description': "Sort field ('indexed' only)", 'type': 'string'}}, 'required': ['query'], 'type': 'object'}, metadata={'title': 'Search code', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1704F40>),
#  StructuredTool(name='search_issues', description='Search for issues in GitHub repositories using issues search syntax already scoped to is:issue', args_schema={'properties': {'order': {'description': 'Sort order', 'enum': ['asc', 'desc'], 'type': 'string'}, 'owner': {'description': 'Optional repository owner. If provided with repo, only issues for this repository are listed.', 'type': 'string'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'query': {'description': 'Search query using GitHub issues search syntax', 'type': 'string'}, 'repo': {'description': 'Optional repository name. If provided with owner, only issues for this repository are listed.', 'type': 'string'}, 'sort': {'description': 'Sort field by number of matches of categories, defaults to best match', 'enum': ['comments', 'reactions', 'reactions-+1', 'reactions--1', 'reactions-smile', 'reactions-thinking_face', 'reactions-heart', 'reactions-tada', 'interactions', 'created', 'updated'], 'type': 'string'}}, 'required': ['query'], 'type': 'object'}, metadata={'title': 'Search issues', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1704FE0>),
#  StructuredTool(name='search_orgs', description='Find GitHub organizations by name, location, or other organization metadata. Ideal for discovering companies, open source foundations, or teams.', args_schema={'properties': {'order': {'description': 'Sort order', 'enum': ['asc', 'desc'], 'type': 'string'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'query': {'description': "Organization search query. Examples: 'microsoft', 'location:california', 'created:>=2025-01-01'. Search is automatically scoped to type:org.", 'type': 'string'}, 'sort': {'description': 'Sort field by category', 'enum': ['followers', 'repositories', 'joined'], 'type': 'string'}}, 'required': ['query'], 'type': 'object'}, metadata={'title': 'Search organizations', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1705080>),
#  StructuredTool(name='search_pull_requests', description='Search for pull requests in GitHub repositories using issues search syntax already scoped to is:pr', args_schema={'properties': {'order': {'description': 'Sort order', 'enum': ['asc', 'desc'], 'type': 'string'}, 'owner': {'description': 'Optional repository owner. If provided with repo, only pull requests for this repository are listed.', 'type': 'string'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'query': {'description': 'Search query using GitHub pull request search syntax', 'type': 'string'}, 'repo': {'description': 'Optional repository name. If provided with owner, only pull requests for this repository are listed.', 'type': 'string'}, 'sort': {'description': 'Sort field by number of matches of categories, defaults to best match', 'enum': ['comments', 'reactions', 'reactions-+1', 'reactions--1', 'reactions-smile', 'reactions-thinking_face', 'reactions-heart', 'reactions-tada', 'interactions', 'created', 'updated'], 'type': 'string'}}, 'required': ['query'], 'type': 'object'}, metadata={'title': 'Search pull requests', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1705120>),
#  StructuredTool(name='search_repositories', description='Find GitHub repositories by name, description, readme, topics, or other metadata. Perfect for discovering projects, finding examples, or locating specific repositories across GitHub.', args_schema={'properties': {'minimal_output': {'default': True, 'description': 'Return minimal repository information (default: true). When false, returns full GitHub API repository objects.', 'type': 'boolean'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'query': {'description': "Repository search query. Examples: 'machine learning in:name stars:>1000 language:python', 'topic:react', 'user:facebook'. Supports advanced search syntax for precise filtering.", 'type': 'string'}}, 'required': ['query'], 'type': 'object'}, metadata={'title': 'Search repositories', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E17051C0>),
#  StructuredTool(name='search_users', description='Find GitHub users by username, real name, or other profile information. Useful for locating developers, contributors, or team members.', args_schema={'properties': {'order': {'description': 'Sort order', 'enum': ['asc', 'desc'], 'type': 'string'}, 'page': {'description': 'Page number for pagination (min 1)', 'minimum': 1, 'type': 'number'}, 'perPage': {'description': 'Results per page for pagination (min 1, max 100)', 'maximum': 100, 'minimum': 1, 'type': 'number'}, 'query': {'description': "User search query. Examples: 'john smith', 'location:seattle', 'followers:>100'. Search is automatically scoped to type:user.", 'type': 'string'}, 'sort': {'description': 'Sort users by number of followers or repositories, or when the person joined GitHub.', 'enum': ['followers', 'repositories', 'joined'], 'type': 'string'}}, 'required': ['query'], 'type': 'object'}, metadata={'title': 'Search users', 'readOnlyHint': True, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1705260>),
#  StructuredTool(name='submit_pending_pull_request_review', description="Submit the requester's latest pending pull request review, normally this is a final step after creating a pending review, adding comments first, unless you know that the user already did the first two steps, you should check before calling this.", args_schema={'properties': {'body': {'description': 'The text of the review comment', 'type': 'string'}, 'event': {'description': 'The event to perform', 'enum': ['APPROVE', 'REQUEST_CHANGES', 'COMMENT'], 'type': 'string'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber', 'event'], 'type': 'object'}, metadata={'title': "Submit the requester's latest pending pull request review", 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1705300>),
#  StructuredTool(name='update_gist', description='Update an existing gist', args_schema={'properties': {'content': {'description': 'Content for the file', 'type': 'string'}, 'description': {'description': 'Updated description of the gist', 'type': 'string'}, 'filename': {'description': 'Filename to update or create', 'type': 'string'}, 'gist_id': {'description': 'ID of the gist to update', 'type': 'string'}}, 'required': ['gist_id', 'filename', 'content'], 'type': 'object'}, metadata={'title': 'Update Gist', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E17053A0>),
#  StructuredTool(name='update_issue', description='Update an existing issue in a GitHub repository.', args_schema={'properties': {'assignees': {'description': 'New assignees', 'items': {'type': 'string'}, 'type': 'array'}, 'body': {'description': 'New description', 'type': 'string'}, 'issue_number': {'description': 'Issue number to update', 'type': 'number'}, 'labels': {'description': 'New labels', 'items': {'type': 'string'}, 'type': 'array'}, 'milestone': {'description': 'New milestone number', 'type': 'number'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'state': {'description': 'New state', 'enum': ['open', 'closed'], 'type': 'string'}, 'title': {'description': 'New title', 'type': 'string'}, 'type': {'description': 'New issue type', 'type': 'string'}}, 'required': ['owner', 'repo', 'issue_number'], 'type': 'object'}, metadata={'title': 'Edit issue', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1705440>),
#  StructuredTool(name='update_pull_request', description='Update an existing pull request in a GitHub repository.', args_schema={'properties': {'base': {'description': 'New base branch name', 'type': 'string'}, 'body': {'description': 'New description', 'type': 'string'}, 'draft': {'description': 'Mark pull request as draft (true) or ready for review (false)', 'type': 'boolean'}, 'maintainer_can_modify': {'description': 'Allow maintainer edits', 'type': 'boolean'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number to update', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}, 'reviewers': {'description': 'GitHub usernames to request reviews from', 'items': {'type': 'string'}, 'type': 'array'}, 'state': {'description': 'New state', 'enum': ['open', 'closed'], 'type': 'string'}, 'title': {'description': 'New title', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber'], 'type': 'object'}, metadata={'title': 'Edit pull request', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E17054E0>),
#  StructuredTool(name='update_pull_request_branch', description='Update the branch of a pull request with the latest changes from the base branch.', args_schema={'properties': {'expectedHeadSha': {'description': "The expected SHA of the pull request's HEAD ref", 'type': 'string'}, 'owner': {'description': 'Repository owner', 'type': 'string'}, 'pullNumber': {'description': 'Pull request number', 'type': 'number'}, 'repo': {'description': 'Repository name', 'type': 'string'}}, 'required': ['owner', 'repo', 'pullNumber'], 'type': 'object'}, metadata={'title': 'Update pull request branch', 'readOnlyHint': False, 'destructiveHint': None, 'idempotentHint': None, 'openWorldHint': None}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x000001C6E1705580>)]

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model='gpt-4o')

# %%
from langgraph.prebuilt import create_react_agent

agent = create_react_agent(
    model=llm,
    tools=tool_list,
    state_modifier=("Use the tools provided to you to answer the user's question")
)

# %%
async def process_stream(stream_generator):
    results = []
    try:
        async for chunk in stream_generator:

            key = list(chunk.keys())[0]
            
            if key == 'agent':
                # Agent 메시지의 내용을 가져옴. 메세지가 비어있는 경우 어떤 도구를 어떻게 호출할지 정보를 가져옴
                content = chunk['agent']['messages'][0].content if chunk['agent']['messages'][0].content != '' else chunk['agent']['messages'][0].additional_kwargs
                print(f"'agent': '{content}'")
            
            elif key == 'tools':
                # 도구 메시지의 내용을 가져옴
                for tool_msg in chunk['tools']['messages']:
                    print(f"'tools': '{tool_msg.content}'")
            
            results.append(chunk)
        return results
    except Exception as e:
        print(f"Error processing stream: {e}")
        return results

# %%
from langchain_core.messages import HumanMessage

query = """깃헙의 Commit 목록을 확인하고 commit 관련 정보를 작성해주세요. 

URL:

"""

stream_generator = agent.astream({'messages': [HumanMessage(content=query)]})


all_chunks = await process_stream(stream_generator)


if all_chunks:
    final_result = all_chunks[-1]
    print(final_result)
# Out:
# 'agent': '{'tool_calls': [{'id': 'call_B0XTJVSyYVvErIbry77g84OO', 'function': {'arguments': '{"owner":"rmfhrm","repo":"AI_agent_work","sha":"618fd1b10d649d5385f4ebe58b7e916968ea15ba"}', 'name': 'get_commit'}, 'type': 'function'}], 'refusal': None}'
# 'tools': '{"sha":"618fd1b10d649d5385f4ebe58b7e916968ea15ba","html_url":"https://github.com/rmfhrm/AI_agent_work/commit/618fd1b10d649d5385f4ebe58b7e916968ea15ba","commit":{"message":"에이전트_음성,이미지\u003e생성형 ai 활용","author":{"name":"rmfhrm","email":"rmfhrm9@gmail.com","date":"2025-08-28T08:35:58Z"},"committer":{"name":"rmfhrm","email":"rmfhrm9@gmail.com","date":"2025-08-28T08:35:58Z"}},"author":{"login":"rmfhrm","id":221989638,"profile_url":"https://github.com/rmfhrm","avatar_url":"https://avatars.githubusercontent.com/u/221989638?v=4"},"committer":{"login":"rmfhrm","id":221989638,"profile_url":"https://github.com/rmfhrm","avatar_url":"https://avatars.githubusercontent.com/u/221989638?v=4"},"stats":{"additions":8471,"total":8471},"files":[{"filename":".gitignore","status":"added","additions":4,"changes":4},{"filename":"audio/1.mp3","status":"added"},{"filename":"audio/guitar_meeting_note_corrected.docx","status":"added"},{"filename":"audio/guitar_meeting_note_corrected.json","status":"added","additions":198,"changes":198},{"filename":"audio/guitar_meeting_note_corrected.md","status":"added","additions":99,"changes":99},{"filename":"audio/guitar_summary.md","status":"added","additions":35,"changes":35},{"filename":"audio/lsy_audio_2023_58s.mp3","status":"added"},{"filename":"audio/싼기타_비싼기타.mp3","status":"added"},{"filename":"audio/싼기타_비싼기타_final.csv","status":"added","additions":149,"changes":149},{"filename":"audio/싼기타_비싼기타_rttm.csv","status":"added","additions":35,"changes":35},{"filename":"audio/싼기타비싼기타.rttm","status":"added","additions":88,"changes":88},{"filename":"gpt_basic.py","status":"added","additions":24,"changes":24},{"filename":"huggingface_whisper.ipynb","status":"added","additions":288,"changes":288},{"filename":"image2_quiz.py","status":"added","additions":112,"changes":112},{"filename":"image_explannation.ipynb","status":"added","additions":483,"changes":483},{"filename":"image_quiz.py","status":"added","additions":124,"changes":124},{"filename":"law.py","status":"added","additions":47,"changes":47},{"filename":"mission01.py","status":"added","additions":64,"changes":64},{"filename":"multi_turn.py","status":"added","additions":31,"changes":31},{"filename":"openai_whisper.ipynb","status":"added","additions":182,"changes":182},{"filename":"output/summary.txt","status":"added","additions":20,"changes":20},{"filename":"output/summary2.txt","status":"added","additions":33,"changes":33},{"filename":"output/과정기반 작물모형을 이용한 웹 기반 밀 재배관리 의사결정 지원시스템 설계 및 구축.txt","status":"added","additions":710,"changes":710},{"filename":"pdf_to.py","status":"added","additions":19,"changes":19},{"filename":"pdf_to_file.py","status":"added","additions":19,"changes":19},{"filename":"pdf_to_without.py","status":"added","additions":28,"changes":28},{"filename":"speaker_diarizaion.ipynb","status":"added","additions":3823,"changes":3823},{"filename":"summarize_and_correct.ipynb","status":"added","additions":1568,"changes":1568},{"filename":"summary.py","status":"added","additions":48,"changes":48},{"filename":"transforemr_pdf.py","status":"added","additions":52,"changes":52}]}'
# 'agent': 'Here are the details for the commit with SHA [618fd1b10d649d5385f4ebe58b7e916968ea15ba](https://github.com/rmfhrm/AI_agent_work/commit/618fd1b10d649d5385f4ebe58b7e916968ea15ba):
#
# - **Commit Message:** 에이전트_음성,이미지>생성형 ai 활용
# - **Author:** [rmfhrm](https://github.com/rmfhrm) (Email: rmfhrm9@gmail.com)
# - **Committer:** [rmfhrm](https://github.com/rmfhrm) (Email: rmfhrm9@gmail.com)
# - **Date:** August 28, 2025
#
# ### Commit Statistics:
# - **Total Additions:** 8,471 lines
#
# ### Files Added:
# 1. **.gitignore** - 4 additions
# 2. **audio/1.mp3**
# 3. **audio/guitar_meeting_note_corrected.docx**
# 4. **audio/guitar_meeting_note_corrected.json** - 198 additions
# 5. **audio/guitar_meeting_note_corrected.md** - 99 additions
# 6. **audio/guitar_summary.md** - 35 additions
# 7. **audio/lsy_audio_2023_58s.mp3**
# 8. **audio/싼기타_비싼기타.mp3**
# 9. **audio/싼기타_비싼기타_final.csv** - 149 additions
# 10. **audio/싼기타_비싼기타_rttm.csv** - 35 additions
# 11. **audio/싼기타비싼기타.rttm** - 88 additions
# 12. **gpt_basic.py** - 24 additions
# 13. **huggingface_whisper.ipynb** - 288 additions
# 14. **image2_quiz.py** - 112 additions
# 15. **image_explannation.ipynb** - 483 additions
# 16. **image_quiz.py** - 124 additions
# 17. **law.py** - 47 additions
# 18. **mission01.py** - 64 additions
# 19. **multi_turn.py** - 31 additions
# 20. **openai_whisper.ipynb** - 182 additions
# 21. **output/summary.txt** - 20 additions
# 22. **output/summary2.txt** - 33 additions
# 23. **output/과정기반 작물모형을 이용한 웹 기반 밀 재배관리 의사결정 지원시스템 설계 및 구축.txt** - 710 additions
# 24. **pdf_to.py** - 19 additions
# 25. **pdf_to_file.py** - 19 additions
# 26. **pdf_to_without.py** - 28 additions
# 27. **speaker_diarizaion.ipynb** - 3,823 additions
# 28. **summarize_and_correct.ipynb** - 1,568 additions
# 29. **summary.py** - 48 additions
# 30. **transforemr_pdf.py** - 52 additions
#
# This commit involved adding a significant number of files and lines, mainly related to audio processing, AI model usage, and summarization.'
# {'agent': {'messages': [AIMessage(content='Here are the details for the commit with SHA [618fd1b10d649d5385f4ebe58b7e916968ea15ba](https://github.com/rmfhrm/AI_agent_work/commit/618fd1b10d649d5385f4ebe58b7e916968ea15ba):\n\n- **Commit Message:** 에이전트_음성,이미지>생성형 ai 활용\n- **Author:** [rmfhrm](https://github.com/rmfhrm) (Email: rmfhrm9@gmail.com)\n- **Committer:** [rmfhrm](https://github.com/rmfhrm) (Email: rmfhrm9@gmail.com)\n- **Date:** August 28, 2025\n\n### Commit Statistics:\n- **Total Additions:** 8,471 lines\n\n### Files Added:\n1. **.gitignore** - 4 additions\n2. **audio/1.mp3**\n3. **audio/guitar_meeting_note_corrected.docx**\n4. **audio/guitar_meeting_note_corrected.json** - 198 additions\n5. **audio/guitar_meeting_note_corrected.md** - 99 additions\n6. **audio/guitar_summary.md** - 35 additions\n7. **audio/lsy_audio_2023_58s.mp3**\n8. **audio/싼기타_비싼기타.mp3**\n9. **audio/싼기타_비싼기타_final.csv** - 149 additions\n10. **audio/싼기타_비싼기타_rttm.csv** - 35 additions\n11. **audio/싼기타비싼기타.rttm** - 88 additions\n12. **gpt_basic.py** - 24 additions\n13. **huggingface_whisper.ipynb** - 288 additions\n14. **image2_quiz.py** - 112 additions\n15. **image_explannation.ipynb** - 483 additions\n16. **image_quiz.py** - 124 additions\n17. **law.py** - 47 additions\n18. **mission01.py** - 64 additions\n19. **multi_turn.py** - 31 additions\n20. **openai_whisper.ipynb** - 182 additions\n21. **output/summary.txt** - 20 additions\n22. **output/summary2.txt** - 33 additions\n23. **output/과정기반 작물모형을 이용한 웹 기반 밀 재배관리 의사결정 지원시스템 설계 및 구축.txt** - 710 additions\n24. **pdf_to.py** - 19 additions\n25. **pdf_to_file.py** - 19 additions\n26. **pdf_to_without.py** - 28 additions\n27. **speaker_diarizaion.ipynb** - 3,823 additions\n28. **summarize_and_correct.ipynb** - 1,568 additions\n29. **summary.py** - 48 additions\n30. **transforemr_pdf.py** - 52 additions\n\nThis commit involved adding a significant number of files and lines, mainly related to audio processing, AI model usage, and summarization.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 697, 'prompt_tokens': 10395, 'total_tokens': 11092, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 9344}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_1827dd0c55', 'finish_reason': 'stop', 'logprobs': None}, id='run--99c55e62-1b7d-479e-b7f7-85bc892450ee-0', usage_metadata={'input_tokens': 10395, 'output_tokens': 697, 'total_tokens': 11092, 'input_token_details': {'audio': 0, 'cache_read': 9344}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}
